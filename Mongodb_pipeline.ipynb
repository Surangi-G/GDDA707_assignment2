# %%
pip install pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from pymongo import MongoClient

# %%
df = pd.read_parquet('student_feedback.parquet')

# %%
df.head()
# Out:
#                             Genre  \
# 0  Academic Support and Resources
# 1  Academic Support and Resources
# 2  Academic Support and Resources
# 3  Academic Support and Resources
# 4  Academic Support and Resources
#
#                                              Reports  Age   Gpa  Year  Count  \
# 0  The limited access to research databases and m...   27  2.18     2      1
# 1  I'm having trouble finding the course material...   23  3.11     2      1
# 2  It's frustrating to have limited access to res...   20  3.68     2      1
# 3  I'm really struggling in one of my classes but...   20  1.30     2      1
# 4   I am really struggling with understanding the...   26  2.50     2      1
#
#   Gender Nationality
# 0      M       Egypt
# 1      F       Egypt
# 2      F       Egypt
# 3      F       Egypt
# 4      F       Egypt

# %%
# Connecting to MongoDB
mongo_uri = 'mongodb+srv://sugunaratna:vc1ym8sTm96NnOZl@cluster0.dnncbje.mongodb.net/?tls=true'  
client = MongoClient(mongo_uri)

# Selecting database and collection
database_name = 'student'  # Replace with your database name
collection_name = 'feedback'  # Replace with your collection name
db = client[database_name]
collection = db[collection_name]
print("Connected to MongoDBb Successfully.")
# Out:
# Connected to MongoDBb Successfully.

# %%
#Converting DataFrame to a list of dictionaries
feedback = df.to_dict(orient='records')

feedback
# Out:
# [{'Genre': 'Academic Support and Resources',
#   'Reports': 'The limited access to research databases and materials is causing a lot of frustration among students. We need better access to be able to succeed academically.',
#   'Age': 27,
#   'Gpa': 2.18,
#   'Year': 2,
#   'Count': 1,
#   'Gender': 'M',
#   'Nationality': 'Egypt'},
#  {'Genre': 'Academic Support and Resources',
#   'Reports': "I'm having trouble finding the course materials I need for my classes. The library doesn't have them and the bookstore is always sold out.",
#   'Age': 23,
#   'Gpa': 3.11,
#   'Year': 2,
#   'Count': 1,
#   'Gender': 'F',
#   'Nationality': 'Egypt'},
#  {'Genre': 'Academic Support and Resources',
#   'Reports': "It's frustrating to have limited access to research databases and materials when I'm trying to write a paper or do a project. I feel like I'm at a disadvantage compared to students at other schools.",
#   'Age': 20,
#   'Gpa': 3.68,
#   'Year': 2,
#   'Count': 1,
#   'Gender': 'F',
# ...

# %%
# Insert data into MongoDB
collection.insert_many(feedback)
print("Student feedback data inserted into MongoDB successfull.")
# Out:
# Student feedback data inserted into MongoDB successfull.

# %%
# Querring to receive feedbacks from international students
results = collection.find({"Genre": "International student experiences"})

# Print the filtered feedbacks
for doc in results:
    print(doc)
# Out:
# {'_id': ObjectId('66c086e239531a7a5febf278'), 'Genre': 'International student experiences', 'Reports': '1. As an international student, I find it difficult to communicate with my peers because of the language barrier. It\'s frustrating because I want to be involved in group projects and extracurricular activities, but I struggle to express myself properly."', 'Age': 23, 'Gpa': 4.0, 'Year': 1, 'Count': 1, 'Gender': 'M', 'Nationality': 'France'}
# {'_id': ObjectId('66c086e239531a7a5febf279'), 'Genre': 'International student experiences', 'Reports': '2. "I feel like there is a cultural gap between me and my classmates. Sometimes I don\'t understand the references they make or the way they approach certain topics. It makes it hard to feel like I\'m truly part of the community."', 'Age': 21, 'Gpa': 1.38, 'Year': 2, 'Count': 1, 'Gender': 'M', 'Nationality': 'France'}
# ...

# %%
# Retrieve all male students above 25 years old
male_above25 = collection.find({"Gender": "M", "Age": {"$gt": 25}})

# Print the filtered documents
for doc in male_above25:
    print(doc)
# Out:
# {'_id': ObjectId('66c086e239531a7a5febf04e'), 'Genre': 'Academic Support and Resources', 'Reports': 'The limited access to research databases and materials is causing a lot of frustration among students. We need better access to be able to succeed academically.', 'Age': 27, 'Gpa': 2.18, 'Year': 2, 'Count': 1, 'Gender': 'M', 'Nationality': 'Egypt'}
# {'_id': ObjectId('66c086e239531a7a5febf075'), 'Genre': 'Academic Support and Resources', 'Reports': "I'm an international student and I'm having trouble accessing some of the online resources because of regional restrictions. It's frustrating to feel like I'm missing out because of where I'm from.", 'Age': 26, 'Gpa': 2.27, 'Year': 2, 'Count': 1, 'Gender': 'M', 'Nationality': 'Egypt'}
# ...

# %%
# Close the connection
client.close()
print("MongoDB connection closed.")
# Out:
# MongoDB connection closed.
